# %%
import pandas as pd

#init data
data1 = {
    'Make':['atv/utv'],
    'Model':['Select Model'],
    'Vendor Code':['NACH'],
    'Vendor Name':['NACHMAN INTERNATIONAL CO. LTD'],
    
    
    'MPN':['MX-05622'],
    
    'AD Item Number':['127526'],
    
    'Vendor Notes':['FRONT MPN ; OEM: 45530-KJ1-701, 45530-KJ1-702'],
}

#lists of models

list_models = [
    
'TRX250',
'TRX250EX Sportrax',
'TRX250R',
'TRX250TE FourTrax Recon ES',
'TRX250TM FourTrax Recon',
'TRX250X',
'TRX250X SE'
    
]

#Range of Years

years = list(range(1986, 2002))

#Functions to generate Dataframes for each model

def generate_df(model, data, year):
    data_copy = data.copy() #creating a copy of data1 to avoid modifying the original
    data_copy['Model'] = model
    data_copy['Year'] = year
    return pd.DataFrame(data_copy)

#Generate DataFrames for all sets of data

dfs = []
for year in years:
    df1 = pd.concat([generate_df(model, data1,year) for model in list_models], ignore_index = True)
    dfs.append(df1)

#Concatenate all DataFrames
final_df = pd.concat(dfs, ignore_index = True)

#Display
final_df
# Out:
#         Make                       Model Vendor Code  \
# 0    atv/utv                      TRX250        NACH
# 1    atv/utv           TRX250EX Sportrax        NACH
# 2    atv/utv                     TRX250R        NACH
# 3    atv/utv  TRX250TE FourTrax Recon ES        NACH
# 4    atv/utv     TRX250TM FourTrax Recon        NACH
# ..       ...                         ...         ...
# 107  atv/utv                     TRX250R        NACH
# 108  atv/utv  TRX250TE FourTrax Recon ES        NACH
# 109  atv/utv     TRX250TM FourTrax Recon        NACH
# 110  atv/utv                     TRX250X        NACH
# 111  atv/utv                  TRX250X SE        NACH
#
#                        Vendor Name       MPN AD Item Number  \
# 0    NACHMAN INTERNATIONAL CO. LTD  MX-05622         127526
# 1    NACHMAN INTERNATIONAL CO. LTD  MX-05622         127526
# 2    NACHMAN INTERNATIONAL CO. LTD  MX-05622         127526
# 3    NACHMAN INTERNATIONAL CO. LTD  MX-05622         127526
# 4    NACHMAN INTERNATIONAL CO. LTD  MX-05622         127526
# ..                             ...       ...            ...
# 107  NACHMAN INTERNATIONAL CO. LTD  MX-05622         127526
# 108  NACHMAN INTERNATIONAL CO. LTD  MX-05622         127526
# 109  NACHMAN INTERNATIONAL CO. LTD  MX-05622         127526
# 110  NACHMAN INTERNATIONAL CO. LTD  MX-05622         127526
# 111  NACHMAN INTERNATIONAL CO. LTD  MX-05622         127526
#
#                                       Vendor Notes  Year
# 0    FRONT MPN ; OEM: 45530-KJ1-701, 45530-KJ1-702  1986
# 1    FRONT MPN ; OEM: 45530-KJ1-701, 45530-KJ1-702  1986
# 2    FRONT MPN ; OEM: 45530-KJ1-701, 45530-KJ1-702  1986
# 3    FRONT MPN ; OEM: 45530-KJ1-701, 45530-KJ1-702  1986
# 4    FRONT MPN ; OEM: 45530-KJ1-701, 45530-KJ1-702  1986
# ..                                             ...   ...
# 107  FRONT MPN ; OEM: 45530-KJ1-701, 45530-KJ1-702  2001
# 108  FRONT MPN ; OEM: 45530-KJ1-701, 45530-KJ1-702  2001
# 109  FRONT MPN ; OEM: 45530-KJ1-701, 45530-KJ1-702  2001
# 110  FRONT MPN ; OEM: 45530-KJ1-701, 45530-KJ1-702  2001
# 111  FRONT MPN ; OEM: 45530-KJ1-701, 45530-KJ1-702  2001
#
# [112 rows x 8 columns]

# %%
file_path = r"C:\Users\User\Desktop\nachmann\2024 TASK\Section 05\08_Section 05 - Master Cyl. Rebuild Kits (12-13-23)\Merge\1.csv"
final_df.to_csv(file_path, index=False)

# %%
import pandas as pd

#init data
data1 = {
    'Make':['atv/utv'],
    'Model':['Select Models'],
    'Vendor Code':['NACH'],
    'Vendor Name':['NACHMAN INTERNATIONAL CO. LTD'],
    
    
    'MPN':['AT-05855'],
    
    'AD Item Number':['128271'],
    
    'Vendor Notes':['FRONT MPN ; OEM: 45530-HN8-006, 45530-MCA-006'],
}

#lists of models

list_models = [
    
'TRX350FE FourTrax Rancher 4x4 ES',
'TRX350FM FourTrax Rancher 4X4',
'TRX350TE FourTrax Rancher ES',
'TRX350TM FourTrax Rancher',
'TRX350',
'TRX400FA FourTrax Rancher AT',
'TRX400FGA FourTrax Rancher AT GPScape',
'TRX420FE FourTrax Rancher 4X4 ES',
'TRX420FM FourTrax Rancher 4X4',
'TRX420FPA Rancher AT 4x4 w/ Power Steering',
'TRX420FPE Rancher ES 4x4 w/ Power Steering',
'TRX420FPM Rancher 4x4 w/ Power Steering',
'TRX420FA Rancher AT',
'TRX420FM1 FourTrax Rancher 4x4',
'TRX420FE1 FourTrax Rancher 4x4 ES',
'TRX420FM2 FourTrax Rancher 4x4 with EPS',
'TRX420FA2 FourTrax Rancher 4x4 Auto DCT with EPS',
'TRX420FA1 FourTrax Rancher 4x4 Auto DCT',
'TRX420FA5 FourTrax Rancher 4x4 Auto DCT IRS',
'TRX420FA6 FourTrax Rancher 4x4 Auto DCT IRS EPS',
'TRX500FA FourTrax Foreman Rubicon',
'TRX500FGA FourTrax Foreman Rubicon GPScape',
'TRX500FE FourTrax Foreman 4x4 ES',
'TRX500FM FourTrax Foreman 4x4',
'TRX500FPE FourTrax Foreman 4x4 ES w/Power Steering',
'TRX500FPM FourTrax Foreman 4x4 w/ Power Steering',
'TRX500TM FourTrax Foreman',
'TRX500FPA FourTrax Foreman Rubicon with EPS',
'TRX500FM1 FourTrax Foreman 4x4',
'TRX500FE1 FourTrax Foreman 4x4 ES',
'TRX500FM2 FourTrax Foreman 4x4 with EPS',
'TRX500FE2 FourTrax Foreman 4x4 ES with EPS',
'TRX500FM5 FourTrax Foreman Rubicon',
'TRX500FM6 FourTrax Foreman Rubicon EPS',
'TRX500FM6D FourTrax Foreman Rubicon EPS DLX',
'TRX500FA5 FourTrax Foreman Rubicon Auto DCT',
'TRX500FA6 FourTrax Foreman Rubicon Auto DCT EPS',
'TRX500FA6D FourTrax Foreman Rubicon Auto DCT EPS D',
'TRX500FA7 FourTrax Foreman Rubicon Auto DCT EPS DL',
'TRX500FM7 FourTrax Foreman Rubicon EPS DLX',
'TRX520FM1 FourTrax Foreman 4x4',
'TRX520FM2 FourTrax Foreman 4x4 EPS',
'TRX520FE2 FourTrax Foreman 4x4 ES EPS',
'TRX520FM6 FourTrax Foreman Rubicon EPS',
'TRX520FA5 FourTrax Foreman Rubicon Auto DCT',
'TRX520FA6 FourTrax Foreman Rubicon Auto DCT EPS',
'TRX520FA7 FourTrax Foreman Rubicon Auto DCT EPS DL',
'TRX650FA FourTrax Rincon',
'TRX650FGA FourTrax Rincon GPScape',
'TRX680FA FourTrax Rincon',
'TRX680FGA FourTrax Rincon GPScape'
    
]

#Range of Years

years = list(range(2003, 2024))

#Functions to generate Dataframes for each model

def generate_df(model, data, year):
    data_copy = data.copy() #creating a copy of data1 to avoid modifying the original
    data_copy['Model'] = model
    data_copy['Year'] = year
    return pd.DataFrame(data_copy)

#Generate DataFrames for all sets of data

dfs = []
for year in years:
    df1 = pd.concat([generate_df(model, data1,year) for model in list_models], ignore_index = True)
    dfs.append(df1)

#Concatenate all DataFrames
final_df = pd.concat(dfs, ignore_index = True)

#Display
final_df
# Out:
#          Make                                              Model Vendor Code  \
# 0     atv/utv                   TRX350FE FourTrax Rancher 4x4 ES        NACH
# 1     atv/utv                      TRX350FM FourTrax Rancher 4X4        NACH
# 2     atv/utv                       TRX350TE FourTrax Rancher ES        NACH
# 3     atv/utv                          TRX350TM FourTrax Rancher        NACH
# 4     atv/utv                                             TRX350        NACH
# ...       ...                                                ...         ...
# 1066  atv/utv  TRX520FA7 FourTrax Foreman Rubicon Auto DCT EP...        NACH
# 1067  atv/utv                           TRX650FA FourTrax Rincon        NACH
# 1068  atv/utv                  TRX650FGA FourTrax Rincon GPScape        NACH
# 1069  atv/utv                           TRX680FA FourTrax Rincon        NACH
# 1070  atv/utv                  TRX680FGA FourTrax Rincon GPScape        NACH
#
#                         Vendor Name       MPN AD Item Number  \
# 0     NACHMAN INTERNATIONAL CO. LTD  AT-05855         128271
# 1     NACHMAN INTERNATIONAL CO. LTD  AT-05855         128271
# 2     NACHMAN INTERNATIONAL CO. LTD  AT-05855         128271
# 3     NACHMAN INTERNATIONAL CO. LTD  AT-05855         128271
# 4     NACHMAN INTERNATIONAL CO. LTD  AT-05855         128271
# ...                             ...       ...            ...
# 1066  NACHMAN INTERNATIONAL CO. LTD  AT-05855         128271
# 1067  NACHMAN INTERNATIONAL CO. LTD  AT-05855         128271
# 1068  NACHMAN INTERNATIONAL CO. LTD  AT-05855         128271
# 1069  NACHMAN INTERNATIONAL CO. LTD  AT-05855         128271
# 1070  NACHMAN INTERNATIONAL CO. LTD  AT-05855         128271
#
#                                        Vendor Notes  Year
# 0     FRONT MPN ; OEM: 45530-HN8-006, 45530-MCA-006  2003
# 1     FRONT MPN ; OEM: 45530-HN8-006, 45530-MCA-006  2003
# 2     FRONT MPN ; OEM: 45530-HN8-006, 45530-MCA-006  2003
# 3     FRONT MPN ; OEM: 45530-HN8-006, 45530-MCA-006  2003
# 4     FRONT MPN ; OEM: 45530-HN8-006, 45530-MCA-006  2003
# ...                                             ...   ...
# 1066  FRONT MPN ; OEM: 45530-HN8-006, 45530-MCA-006  2023
# 1067  FRONT MPN ; OEM: 45530-HN8-006, 45530-MCA-006  2023
# 1068  FRONT MPN ; OEM: 45530-HN8-006, 45530-MCA-006  2023
# 1069  FRONT MPN ; OEM: 45530-HN8-006, 45530-MCA-006  2023
# 1070  FRONT MPN ; OEM: 45530-HN8-006, 45530-MCA-006  2023
#
# [1071 rows x 8 columns]

# %%
file_path = r"C:\Users\User\Desktop\nachmann\2024 TASK\Section 05\08_Section 05 - Master Cyl. Rebuild Kits (12-13-23)\Merge\2.csv"
final_df.to_csv(file_path, index=False)

# %%
import pandas as pd

#init data
data1 = {
    'Make':['atv/utv'],
    'Model':['Select Models'],
    'Vendor Code':['NACH'],
    'Vendor Name':['NACHMAN INTERNATIONAL CO. LTD'],
    
    
    'MPN':['AT-05863'],
    
    'AD Item Number':['128272'],
    
    'Vendor Notes':['FRONT MPN ; OEM: 5D3-W0041-00'],
}

#lists of models

list_models = [
    
'YFM125 Grizzly',
'YFM250 Raptor',
'YFM250 Raptor SE',
'YFM250 Raptor SE Custom',
'YFM700R Raptor',
'YFM700R Raptor GYTR Edition',
'YFM700R Raptor SE',
'YFM550 Grizzly FI 4x4 Auto',
'YFM550 Grizzly FI 4x4 Auto EPS',
'YFM125 Raptor',
'YFM250R Raptor',
'YFM700 Raptor',
'YFZ450',
'YFZ450R'

    
]

#Range of Years

years = list(range(2007, 2023))

#Functions to generate Dataframes for each model

def generate_df(model, data, year):
    data_copy = data.copy() #creating a copy of data1 to avoid modifying the original
    data_copy['Model'] = model
    data_copy['Year'] = year
    return pd.DataFrame(data_copy)

#Generate DataFrames for all sets of data

dfs = []
for year in years:
    df1 = pd.concat([generate_df(model, data1,year) for model in list_models], ignore_index = True)
    dfs.append(df1)

#Concatenate all DataFrames
final_df = pd.concat(dfs, ignore_index = True)

#Display
final_df
# Out:
#         Make                    Model Vendor Code  \
# 0    atv/utv           YFM125 Grizzly        NACH
# 1    atv/utv            YFM250 Raptor        NACH
# 2    atv/utv         YFM250 Raptor SE        NACH
# 3    atv/utv  YFM250 Raptor SE Custom        NACH
# 4    atv/utv           YFM700R Raptor        NACH
# ..       ...                      ...         ...
# 219  atv/utv            YFM125 Raptor        NACH
# 220  atv/utv           YFM250R Raptor        NACH
# 221  atv/utv            YFM700 Raptor        NACH
# 222  atv/utv                   YFZ450        NACH
# 223  atv/utv                  YFZ450R        NACH
#
#                        Vendor Name       MPN AD Item Number  \
# 0    NACHMAN INTERNATIONAL CO. LTD  AT-05863         128272
# 1    NACHMAN INTERNATIONAL CO. LTD  AT-05863         128272
# 2    NACHMAN INTERNATIONAL CO. LTD  AT-05863         128272
# 3    NACHMAN INTERNATIONAL CO. LTD  AT-05863         128272
# 4    NACHMAN INTERNATIONAL CO. LTD  AT-05863         128272
# ..                             ...       ...            ...
# 219  NACHMAN INTERNATIONAL CO. LTD  AT-05863         128272
# 220  NACHMAN INTERNATIONAL CO. LTD  AT-05863         128272
# 221  NACHMAN INTERNATIONAL CO. LTD  AT-05863         128272
# 222  NACHMAN INTERNATIONAL CO. LTD  AT-05863         128272
# 223  NACHMAN INTERNATIONAL CO. LTD  AT-05863         128272
#
#                       Vendor Notes  Year
# 0    FRONT MPN ; OEM: 5D3-W0041-00  2007
# 1    FRONT MPN ; OEM: 5D3-W0041-00  2007
# 2    FRONT MPN ; OEM: 5D3-W0041-00  2007
# 3    FRONT MPN ; OEM: 5D3-W0041-00  2007
# 4    FRONT MPN ; OEM: 5D3-W0041-00  2007
# ..                             ...   ...
# 219  FRONT MPN ; OEM: 5D3-W0041-00  2022
# 220  FRONT MPN ; OEM: 5D3-W0041-00  2022
# 221  FRONT MPN ; OEM: 5D3-W0041-00  2022
# 222  FRONT MPN ; OEM: 5D3-W0041-00  2022
# 223  FRONT MPN ; OEM: 5D3-W0041-00  2022
#
# [224 rows x 8 columns]

# %%
file_path = r"C:\Users\User\Desktop\nachmann\2024 TASK\Section 05\08_Section 05 - Master Cyl. Rebuild Kits (12-13-23)\Merge\3.csv"
final_df.to_csv(file_path, index=False)

# %%
import pandas as pd

#init data
data1 = {
    'Make':['atv/utv'],
    'Model':['Select Models'],
    'Vendor Code':['NACH'],
    'Vendor Name':['NACHMAN INTERNATIONAL CO. LTD'],
    
    
    'MPN':['AT-05866'],
    
    'AD Item Number':['128273'],
    
    'Vendor Notes':['REAR MPN ; OEM: 5FK-W0042-50'],
}

#lists of models

list_models = [
    
'YFM350 Raptor',
'YFZ350 Banshee'


    
]

#Range of Years

years = list(range(2002, 2014))

#Functions to generate Dataframes for each model

def generate_df(model, data, year):
    data_copy = data.copy() #creating a copy of data1 to avoid modifying the original
    data_copy['Model'] = model
    data_copy['Year'] = year
    return pd.DataFrame(data_copy)

#Generate DataFrames for all sets of data

dfs = []
for year in years:
    df1 = pd.concat([generate_df(model, data1,year) for model in list_models], ignore_index = True)
    dfs.append(df1)

#Concatenate all DataFrames
final_df = pd.concat(dfs, ignore_index = True)

#Display
final_df
# Out:
#        Make           Model Vendor Code                    Vendor Name  \
# 0   atv/utv   YFM350 Raptor        NACH  NACHMAN INTERNATIONAL CO. LTD
# 1   atv/utv  YFZ350 Banshee        NACH  NACHMAN INTERNATIONAL CO. LTD
# 2   atv/utv   YFM350 Raptor        NACH  NACHMAN INTERNATIONAL CO. LTD
# 3   atv/utv  YFZ350 Banshee        NACH  NACHMAN INTERNATIONAL CO. LTD
# 4   atv/utv   YFM350 Raptor        NACH  NACHMAN INTERNATIONAL CO. LTD
# 5   atv/utv  YFZ350 Banshee        NACH  NACHMAN INTERNATIONAL CO. LTD
# 6   atv/utv   YFM350 Raptor        NACH  NACHMAN INTERNATIONAL CO. LTD
# 7   atv/utv  YFZ350 Banshee        NACH  NACHMAN INTERNATIONAL CO. LTD
# 8   atv/utv   YFM350 Raptor        NACH  NACHMAN INTERNATIONAL CO. LTD
# 9   atv/utv  YFZ350 Banshee        NACH  NACHMAN INTERNATIONAL CO. LTD
# 10  atv/utv   YFM350 Raptor        NACH  NACHMAN INTERNATIONAL CO. LTD
# 11  atv/utv  YFZ350 Banshee        NACH  NACHMAN INTERNATIONAL CO. LTD
# 12  atv/utv   YFM350 Raptor        NACH  NACHMAN INTERNATIONAL CO. LTD
# 13  atv/utv  YFZ350 Banshee        NACH  NACHMAN INTERNATIONAL CO. LTD
# 14  atv/utv   YFM350 Raptor        NACH  NACHMAN INTERNATIONAL CO. LTD
# 15  atv/utv  YFZ350 Banshee        NACH  NACHMAN INTERNATIONAL CO. LTD
# 16  atv/utv   YFM350 Raptor        NACH  NACHMAN INTERNATIONAL CO. LTD
# 17  atv/utv  YFZ350 Banshee        NACH  NACHMAN INTERNATIONAL CO. LTD
# 18  atv/utv   YFM350 Raptor        NACH  NACHMAN INTERNATIONAL CO. LTD
# 19  atv/utv  YFZ350 Banshee        NACH  NACHMAN INTERNATIONAL CO. LTD
# 20  atv/utv   YFM350 Raptor        NACH  NACHMAN INTERNATIONAL CO. LTD
# 21  atv/utv  YFZ350 Banshee        NACH  NACHMAN INTERNATIONAL CO. LTD
# 22  atv/utv   YFM350 Raptor        NACH  NACHMAN INTERNATIONAL CO. LTD
# 23  atv/utv  YFZ350 Banshee        NACH  NACHMAN INTERNATIONAL CO. LTD
#
#          MPN AD Item Number                  Vendor Notes  Year
# 0   AT-05866         128273  REAR MPN ; OEM: 5FK-W0042-50  2002
# 1   AT-05866         128273  REAR MPN ; OEM: 5FK-W0042-50  2002
# 2   AT-05866         128273  REAR MPN ; OEM: 5FK-W0042-50  2003
# 3   AT-05866         128273  REAR MPN ; OEM: 5FK-W0042-50  2003
# 4   AT-05866         128273  REAR MPN ; OEM: 5FK-W0042-50  2004
# 5   AT-05866         128273  REAR MPN ; OEM: 5FK-W0042-50  2004
# 6   AT-05866         128273  REAR MPN ; OEM: 5FK-W0042-50  2005
# 7   AT-05866         128273  REAR MPN ; OEM: 5FK-W0042-50  2005
# 8   AT-05866         128273  REAR MPN ; OEM: 5FK-W0042-50  2006
# 9   AT-05866         128273  REAR MPN ; OEM: 5FK-W0042-50  2006
# 10  AT-05866         128273  REAR MPN ; OEM: 5FK-W0042-50  2007
# 11  AT-05866         128273  REAR MPN ; OEM: 5FK-W0042-50  2007
# 12  AT-05866         128273  REAR MPN ; OEM: 5FK-W0042-50  2008
# 13  AT-05866         128273  REAR MPN ; OEM: 5FK-W0042-50  2008
# 14  AT-05866         128273  REAR MPN ; OEM: 5FK-W0042-50  2009
# 15  AT-05866         128273  REAR MPN ; OEM: 5FK-W0042-50  2009
# 16  AT-05866         128273  REAR MPN ; OEM: 5FK-W0042-50  2010
# 17  AT-05866         128273  REAR MPN ; OEM: 5FK-W0042-50  2010
# 18  AT-05866         128273  REAR MPN ; OEM: 5FK-W0042-50  2011
# 19  AT-05866         128273  REAR MPN ; OEM: 5FK-W0042-50  2011
# 20  AT-05866         128273  REAR MPN ; OEM: 5FK-W0042-50  2012
# 21  AT-05866         128273  REAR MPN ; OEM: 5FK-W0042-50  2012
# 22  AT-05866         128273  REAR MPN ; OEM: 5FK-W0042-50  2013
# 23  AT-05866         128273  REAR MPN ; OEM: 5FK-W0042-50  2013

# %%
file_path = r"C:\Users\User\Desktop\nachmann\2024 TASK\Section 05\08_Section 05 - Master Cyl. Rebuild Kits (12-13-23)\Merge\4.csv"
final_df.to_csv(file_path, index=False)

# %%
import pandas as pd

#init data
data1 = {
    'Make':['atv/utv'],
    'Model':['Select Models'],
    'Vendor Code':['NACH'],
    'Vendor Name':['NACHMAN INTERNATIONAL CO. LTD'],
    
    
    'MPN':['AT-05867'],
    
    'AD Item Number':['128274'],
    
    'Vendor Notes':['FRONT MPN ; OEM: 2010196, 2010238'],
}

#lists of models

list_models = [
    
'Sportsman 300',
'ATP 330',
'Magnum 330 2x4',
'Magnum 330 4x4',
'Trail Blazer 330',
'Trail Boss 330',
'Sportsman 400',
'Sportsman 450',
'Sportsman 400 4x4',
'ATP 500',
'Scrambler 500 2x4',
'Scrambler 500 4x4',
'Sportsman 500 4x4',
'Sportsman 500 6x6',
'Sportsman 550 X2',
'Sportsman 550',
'Sportsman 600',
'Sportsman 700',
'Sportsman 800 EFI',
'Sportsman 850 EFI XP',
'Sportsman 850 EFI XP w/ EPS',
'Sportsman 800 EFI 6x6 Big Boss',
'Sportsman 800 6x6 Big Boss',
'Sportsman 850 HO XP',
'Sportsman Forest 800 6x6',
'Sportsman 850'


    
]

#Range of Years

years = list(range(1994, 2016))

#Functions to generate Dataframes for each model

def generate_df(model, data, year):
    data_copy = data.copy() #creating a copy of data1 to avoid modifying the original
    data_copy['Model'] = model
    data_copy['Year'] = year
    return pd.DataFrame(data_copy)

#Generate DataFrames for all sets of data

dfs = []
for year in years:
    df1 = pd.concat([generate_df(model, data1,year) for model in list_models], ignore_index = True)
    dfs.append(df1)

#Concatenate all DataFrames
final_df = pd.concat(dfs, ignore_index = True)

#Display
final_df
# Out:
#         Make                           Model Vendor Code  \
# 0    atv/utv                   Sportsman 300        NACH
# 1    atv/utv                         ATP 330        NACH
# 2    atv/utv                  Magnum 330 2x4        NACH
# 3    atv/utv                  Magnum 330 4x4        NACH
# 4    atv/utv                Trail Blazer 330        NACH
# ..       ...                             ...         ...
# 567  atv/utv  Sportsman 800 EFI 6x6 Big Boss        NACH
# 568  atv/utv      Sportsman 800 6x6 Big Boss        NACH
# 569  atv/utv             Sportsman 850 HO XP        NACH
# 570  atv/utv        Sportsman Forest 800 6x6        NACH
# 571  atv/utv                   Sportsman 850        NACH
#
#                        Vendor Name       MPN AD Item Number  \
# 0    NACHMAN INTERNATIONAL CO. LTD  AT-05867         128274
# 1    NACHMAN INTERNATIONAL CO. LTD  AT-05867         128274
# 2    NACHMAN INTERNATIONAL CO. LTD  AT-05867         128274
# 3    NACHMAN INTERNATIONAL CO. LTD  AT-05867         128274
# 4    NACHMAN INTERNATIONAL CO. LTD  AT-05867         128274
# ..                             ...       ...            ...
# 567  NACHMAN INTERNATIONAL CO. LTD  AT-05867         128274
# 568  NACHMAN INTERNATIONAL CO. LTD  AT-05867         128274
# 569  NACHMAN INTERNATIONAL CO. LTD  AT-05867         128274
# 570  NACHMAN INTERNATIONAL CO. LTD  AT-05867         128274
# 571  NACHMAN INTERNATIONAL CO. LTD  AT-05867         128274
#
#                           Vendor Notes  Year
# 0    FRONT MPN ; OEM: 2010196, 2010238  1994
# 1    FRONT MPN ; OEM: 2010196, 2010238  1994
# 2    FRONT MPN ; OEM: 2010196, 2010238  1994
# 3    FRONT MPN ; OEM: 2010196, 2010238  1994
# 4    FRONT MPN ; OEM: 2010196, 2010238  1994
# ..                                 ...   ...
# 567  FRONT MPN ; OEM: 2010196, 2010238  2015
# 568  FRONT MPN ; OEM: 2010196, 2010238  2015
# 569  FRONT MPN ; OEM: 2010196, 2010238  2015
# 570  FRONT MPN ; OEM: 2010196, 2010238  2015
# 571  FRONT MPN ; OEM: 2010196, 2010238  2015
#
# [572 rows x 8 columns]

# %%
file_path = r"C:\Users\User\Desktop\nachmann\2024 TASK\Section 05\08_Section 05 - Master Cyl. Rebuild Kits (12-13-23)\Merge\5.csv"
final_df.to_csv(file_path, index=False)

# %%
import pandas as pd

#init data
data1 = {
    'Make':['atv/utv'],
    'Model':['Select Models'],
    'Vendor Code':['NACH'],
    'Vendor Name':['NACHMAN INTERNATIONAL CO. LTD'],
    
    
    'MPN':['MX-05618'],
    
    'AD Item Number':['127522'],
    
    'Vendor Notes':['FRONT MPN ; OEM: 2010196, 2010238'],
}

#lists of models

list_models = [
    
'KFX450R'

    
]

#Range of Years

years = list(range(2008, 2015))

#Functions to generate Dataframes for each model

def generate_df(model, data, year):
    data_copy = data.copy() #creating a copy of data1 to avoid modifying the original
    data_copy['Model'] = model
    data_copy['Year'] = year
    return pd.DataFrame(data_copy)

#Generate DataFrames for all sets of data

dfs = []
for year in years:
    df1 = pd.concat([generate_df(model, data1,year) for model in list_models], ignore_index = True)
    dfs.append(df1)

#Concatenate all DataFrames
final_df = pd.concat(dfs, ignore_index = True)

#Display
final_df
# Out:
#       Make    Model Vendor Code                    Vendor Name       MPN  \
# 0  atv/utv  KFX450R        NACH  NACHMAN INTERNATIONAL CO. LTD  MX-05618
# 1  atv/utv  KFX450R        NACH  NACHMAN INTERNATIONAL CO. LTD  MX-05618
# 2  atv/utv  KFX450R        NACH  NACHMAN INTERNATIONAL CO. LTD  MX-05618
# 3  atv/utv  KFX450R        NACH  NACHMAN INTERNATIONAL CO. LTD  MX-05618
# 4  atv/utv  KFX450R        NACH  NACHMAN INTERNATIONAL CO. LTD  MX-05618
# 5  atv/utv  KFX450R        NACH  NACHMAN INTERNATIONAL CO. LTD  MX-05618
# 6  atv/utv  KFX450R        NACH  NACHMAN INTERNATIONAL CO. LTD  MX-05618
#
#   AD Item Number                       Vendor Notes  Year
# 0         127522  FRONT MPN ; OEM: 2010196, 2010238  2008
# 1         127522  FRONT MPN ; OEM: 2010196, 2010238  2009
# 2         127522  FRONT MPN ; OEM: 2010196, 2010238  2010
# 3         127522  FRONT MPN ; OEM: 2010196, 2010238  2011
# 4         127522  FRONT MPN ; OEM: 2010196, 2010238  2012
# 5         127522  FRONT MPN ; OEM: 2010196, 2010238  2013
# 6         127522  FRONT MPN ; OEM: 2010196, 2010238  2014

# %%
file_path = r"C:\Users\User\Desktop\nachmann\2024 TASK\Section 05\08_Section 05 - Master Cyl. Rebuild Kits (12-13-23)\Merge\6.csv"
final_df.to_csv(file_path, index=False)

# %%
import pandas as pd

#init data
data1 = {
    'Make':['atv/utv'],
    'Model':['Select Models'],
    'Vendor Code':['NACH'],
    'Vendor Name':['NACHMAN INTERNATIONAL CO. LTD'],
    
    
    'MPN':['MX-05621'],
    
    'AD Item Number':['127525'],
    
    'Vendor Notes':['FRONT MPN ; OEM: 59600-04810, 59600-36820'],
}

#lists of models

list_models = [
    
'LT230E QuadRunner',
'LT230S QuadSport',
'LT-4WD QuadRunner 250',
'LT-F4WDX King Quad 300',
'LT-R450 QuadRacer',
'LT-Z250 QuadSport Z',
'LT-Z400 QuadSport Z',
'LT-A750X KingQuad AXi 4x4',
'LT-F230',
'LT-A500 KingQuad AXi',
'LT-A500 KingQuad AXi Power Steering',
'LT-A750 KingQuad AXi Power Steering',
'LT-Z400 QuadSport Z LE',
'LT-A750X KingQuad AXi 4x4 LE',
'LT-A750 KingQuad AXi Power Steering LE',
'LT-A500 KingQuad AXi Power Steering SE',
'LT-A750 KingQuad AXi Power Steering SE',
'LT-A750 KingQuad AXi Power Steering SE Rugged',
'LT-A500 KingQuad AXi Power Steering SE Rugged',
'LT-A500 KingQuad AXi Power Steering SE+',
'LT-A750 KingQuad AXi Power Steering SE+',
'LT-A500 KingQuad AXi Power Steering Rugged',
'LT-A500 KingQuad AXi Power Steering SE+ Rugged',
'LT-A750 KingQuad AXi Power Steering Rugged',
'LT-A750 KingQuad AXi Power Steering SE+ Rugged',
'LT300E',
'LT500R QuadRacer',
'LT-A500F QuadMaster',
'LT-A500F Vinson 500 4x4 Auto'

    
]

#Range of Years

years = list(range(1985, 2014))

#Functions to generate Dataframes for each model

def generate_df(model, data, year):
    data_copy = data.copy() #creating a copy of data1 to avoid modifying the original
    data_copy['Model'] = model
    data_copy['Year'] = year
    return pd.DataFrame(data_copy)

#Generate DataFrames for all sets of data

dfs = []
for year in years:
    df1 = pd.concat([generate_df(model, data1,year) for model in list_models], ignore_index = True)
    dfs.append(df1)

#Concatenate all DataFrames
final_df = pd.concat(dfs, ignore_index = True)

#Display
final_df
# Out:
#         Make                                           Model Vendor Code  \
# 0    atv/utv                               LT230E QuadRunner        NACH
# 1    atv/utv                                LT230S QuadSport        NACH
# 2    atv/utv                           LT-4WD QuadRunner 250        NACH
# 3    atv/utv                          LT-F4WDX King Quad 300        NACH
# 4    atv/utv                               LT-R450 QuadRacer        NACH
# ..       ...                                             ...         ...
# 836  atv/utv  LT-A750 KingQuad AXi Power Steering SE+ Rugged        NACH
# 837  atv/utv                                          LT300E        NACH
# 838  atv/utv                                LT500R QuadRacer        NACH
# 839  atv/utv                             LT-A500F QuadMaster        NACH
# 840  atv/utv                    LT-A500F Vinson 500 4x4 Auto        NACH
#
#                        Vendor Name       MPN AD Item Number  \
# 0    NACHMAN INTERNATIONAL CO. LTD  MX-05621         127525
# 1    NACHMAN INTERNATIONAL CO. LTD  MX-05621         127525
# 2    NACHMAN INTERNATIONAL CO. LTD  MX-05621         127525
# 3    NACHMAN INTERNATIONAL CO. LTD  MX-05621         127525
# 4    NACHMAN INTERNATIONAL CO. LTD  MX-05621         127525
# ..                             ...       ...            ...
# 836  NACHMAN INTERNATIONAL CO. LTD  MX-05621         127525
# 837  NACHMAN INTERNATIONAL CO. LTD  MX-05621         127525
# 838  NACHMAN INTERNATIONAL CO. LTD  MX-05621         127525
# 839  NACHMAN INTERNATIONAL CO. LTD  MX-05621         127525
# 840  NACHMAN INTERNATIONAL CO. LTD  MX-05621         127525
#
#                                   Vendor Notes  Year
# 0    FRONT MPN ; OEM: 59600-04810, 59600-36820  1985
# 1    FRONT MPN ; OEM: 59600-04810, 59600-36820  1985
# 2    FRONT MPN ; OEM: 59600-04810, 59600-36820  1985
# 3    FRONT MPN ; OEM: 59600-04810, 59600-36820  1985
# 4    FRONT MPN ; OEM: 59600-04810, 59600-36820  1985
# ..                                         ...   ...
# 836  FRONT MPN ; OEM: 59600-04810, 59600-36820  2013
# 837  FRONT MPN ; OEM: 59600-04810, 59600-36820  2013
# 838  FRONT MPN ; OEM: 59600-04810, 59600-36820  2013
# 839  FRONT MPN ; OEM: 59600-04810, 59600-36820  2013
# 840  FRONT MPN ; OEM: 59600-04810, 59600-36820  2013
#
# [841 rows x 8 columns]

# %%
file_path = r"C:\Users\User\Desktop\nachmann\2024 TASK\Section 05\08_Section 05 - Master Cyl. Rebuild Kits (12-13-23)\Merge\7.csv"
final_df.to_csv(file_path, index=False)

# %%
import pandas as pd

#init data
data1 = {
    'Make':['atv/utv'],
    'Model':['Select Models'],
    'Vendor Code':['NACH'],
    'Vendor Name':['NACHMAN INTERNATIONAL CO. LTD'],
    
    
    'MPN':['MX-05635'],
    
    'AD Item Number':['999672'],
    
    'Vendor Notes':[pd.NA],
}

#lists of models

list_models = [
    
'TRX250',
'TRX250X',
'TRX450ER Electric Start',
'TRX450R',
'TRX70',
'TRX700XX',
'TRX300X',
'TRX250X SE',
'KEF300 Lakota Sport',
'KEF300 Lakota Utility',
'LT230E QuadRunner',
'LT230S QuadSport',
'LT250R QuadRacer',
'LT250S',
'LT500R QuadRacer',
'LT-A500F Vinson 500 4x4 Auto'

    
]

#Range of Years

years = list(range(1985, 2024))

#Functions to generate Dataframes for each model

def generate_df(model, data, year):
    data_copy = data.copy() #creating a copy of data1 to avoid modifying the original
    data_copy['Model'] = model
    data_copy['Year'] = year
    return pd.DataFrame(data_copy)

#Generate DataFrames for all sets of data

dfs = []
for year in years:
    df1 = pd.concat([generate_df(model, data1,year) for model in list_models], ignore_index = True)
    dfs.append(df1)

#Concatenate all DataFrames
final_df = pd.concat(dfs, ignore_index = True)

#Display
final_df
# Out:
#         Make                         Model Vendor Code  \
# 0    atv/utv                        TRX250        NACH
# 1    atv/utv                       TRX250X        NACH
# 2    atv/utv       TRX450ER Electric Start        NACH
# 3    atv/utv                       TRX450R        NACH
# 4    atv/utv                         TRX70        NACH
# ..       ...                           ...         ...
# 619  atv/utv              LT230S QuadSport        NACH
# 620  atv/utv              LT250R QuadRacer        NACH
# 621  atv/utv                        LT250S        NACH
# 622  atv/utv              LT500R QuadRacer        NACH
# 623  atv/utv  LT-A500F Vinson 500 4x4 Auto        NACH
#
#                        Vendor Name       MPN AD Item Number Vendor Notes  Year
# 0    NACHMAN INTERNATIONAL CO. LTD  MX-05635         999672         <NA>  1985
# 1    NACHMAN INTERNATIONAL CO. LTD  MX-05635         999672         <NA>  1985
# 2    NACHMAN INTERNATIONAL CO. LTD  MX-05635         999672         <NA>  1985
# 3    NACHMAN INTERNATIONAL CO. LTD  MX-05635         999672         <NA>  1985
# 4    NACHMAN INTERNATIONAL CO. LTD  MX-05635         999672         <NA>  1985
# ..                             ...       ...            ...          ...   ...
# 619  NACHMAN INTERNATIONAL CO. LTD  MX-05635         999672         <NA>  2023
# 620  NACHMAN INTERNATIONAL CO. LTD  MX-05635         999672         <NA>  2023
# 621  NACHMAN INTERNATIONAL CO. LTD  MX-05635         999672         <NA>  2023
# 622  NACHMAN INTERNATIONAL CO. LTD  MX-05635         999672         <NA>  2023
# 623  NACHMAN INTERNATIONAL CO. LTD  MX-05635         999672         <NA>  2023
#
# [624 rows x 8 columns]

# %%
file_path = r"C:\Users\User\Desktop\nachmann\2024 TASK\Section 05\08_Section 05 - Master Cyl. Rebuild Kits (12-13-23)\Merge\8.csv"
final_df.to_csv(file_path, index=False)

# %%
import pandas as pd

#init data
data1 = {
    'Make':['atv/utv'],
    'Model':['Select Models'],
    'Vendor Code':['NACH'],
    'Vendor Name':['NACHMAN INTERNATIONAL CO. LTD'],
    
    
    'MPN':['SM-05412'],
    
    'AD Item Number':['999563'],
    
    'Vendor Notes':['FRONT MPN ; OEM: 8CR-W0041-00, 8CR-W2587-00'],
}

#lists of models

list_models = [
    
'YFM250 Big Bear',
'YFM250 Bruin',
'YFM350 Bruin Auto 2x4',
'YFM350FA Bruin Auto 4x4',
'YFM350 Grizzly 4x4 Auto',
'YFM350 Grizzly Auto',
'YFM350 Grizzly IRS 4x4 Auto',
'YFM350 Wolverine',
'400 2x4',
'400 2x4 Auto',
'400 4x4',
'400 4x4 ACT',
'400 4x4 Auto',
'400 2x4 FIS',
'YFM400 Big Bear 2x4',
'YFM400 Big Bear 4x4',
'YFM400 Big Bear IRS 4x4',
'YFM400 Grizzly 4x4 Auto',
'YFM400A Kodiak',
'YFM400F Kodiak 4x4',
'YFM450 Grizzly 4x4 Auto',
'YFM450F Kodiak Auto 4x4',
'YFM450FX Wolverine 4x4',
'YFM450 Grizzly 4x4 Auto IRS',
'YFM450 Grizzly 4x4 Auto EPS',
'YFM450 Kodiak 450',
'YFM450 Kodiak 450 EPS',
'YFM450 Kodiak 450 EPS SE',
'YFM660F Grizzly 4x4',
'YFM250 Bear Tracker'


    
]

#Range of Years

years = list(range(2002, 2014))

#Functions to generate Dataframes for each model

def generate_df(model, data, year):
    data_copy = data.copy() #creating a copy of data1 to avoid modifying the original
    data_copy['Model'] = model
    data_copy['Year'] = year
    return pd.DataFrame(data_copy)

#Generate DataFrames for all sets of data

dfs = []
for year in years:
    df1 = pd.concat([generate_df(model, data1,year) for model in list_models], ignore_index = True)
    dfs.append(df1)

#Concatenate all DataFrames
final_df = pd.concat(dfs, ignore_index = True)

#Display
final_df
# Out:
#         Make                     Model Vendor Code  \
# 0    atv/utv           YFM250 Big Bear        NACH
# 1    atv/utv              YFM250 Bruin        NACH
# 2    atv/utv     YFM350 Bruin Auto 2x4        NACH
# 3    atv/utv   YFM350FA Bruin Auto 4x4        NACH
# 4    atv/utv   YFM350 Grizzly 4x4 Auto        NACH
# ..       ...                       ...         ...
# 355  atv/utv         YFM450 Kodiak 450        NACH
# 356  atv/utv     YFM450 Kodiak 450 EPS        NACH
# 357  atv/utv  YFM450 Kodiak 450 EPS SE        NACH
# 358  atv/utv       YFM660F Grizzly 4x4        NACH
# 359  atv/utv       YFM250 Bear Tracker        NACH
#
#                        Vendor Name       MPN AD Item Number  \
# 0    NACHMAN INTERNATIONAL CO. LTD  SM-05412         999563
# 1    NACHMAN INTERNATIONAL CO. LTD  SM-05412         999563
# 2    NACHMAN INTERNATIONAL CO. LTD  SM-05412         999563
# 3    NACHMAN INTERNATIONAL CO. LTD  SM-05412         999563
# 4    NACHMAN INTERNATIONAL CO. LTD  SM-05412         999563
# ..                             ...       ...            ...
# 355  NACHMAN INTERNATIONAL CO. LTD  SM-05412         999563
# 356  NACHMAN INTERNATIONAL CO. LTD  SM-05412         999563
# 357  NACHMAN INTERNATIONAL CO. LTD  SM-05412         999563
# 358  NACHMAN INTERNATIONAL CO. LTD  SM-05412         999563
# 359  NACHMAN INTERNATIONAL CO. LTD  SM-05412         999563
#
#                                     Vendor Notes  Year
# 0    FRONT MPN ; OEM: 8CR-W0041-00, 8CR-W2587-00  2002
# 1    FRONT MPN ; OEM: 8CR-W0041-00, 8CR-W2587-00  2002
# 2    FRONT MPN ; OEM: 8CR-W0041-00, 8CR-W2587-00  2002
# 3    FRONT MPN ; OEM: 8CR-W0041-00, 8CR-W2587-00  2002
# 4    FRONT MPN ; OEM: 8CR-W0041-00, 8CR-W2587-00  2002
# ..                                           ...   ...
# 355  FRONT MPN ; OEM: 8CR-W0041-00, 8CR-W2587-00  2013
# 356  FRONT MPN ; OEM: 8CR-W0041-00, 8CR-W2587-00  2013
# 357  FRONT MPN ; OEM: 8CR-W0041-00, 8CR-W2587-00  2013
# 358  FRONT MPN ; OEM: 8CR-W0041-00, 8CR-W2587-00  2013
# 359  FRONT MPN ; OEM: 8CR-W0041-00, 8CR-W2587-00  2013
#
# [360 rows x 8 columns]

# %%
file_path = r"C:\Users\User\Desktop\nachmann\2024 TASK\Section 05\08_Section 05 - Master Cyl. Rebuild Kits (12-13-23)\Merge\9.csv"
final_df.to_csv(file_path, index=False)
